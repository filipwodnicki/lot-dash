# %%
import geocoder

import geocoder
g = geocoder.osm('ORD Chicago, IL airport')
g.json
print( g.lat, g.lng)
# Out:
# 41.9779849 -87.9093214054785

# %%
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker

from app.models import Airport, AirportGEO

engine = create_engine('sqlite:////Users/Filip/code/python/lot-dash/app.db')
DBSession = sessionmaker(bind=engine)
session = DBSession()
# Out:
# [2018-09-13 21:47:10,850] INFO in __init__: Microblog startup

# %%
airports = Airport.query.all()

# %%
for i, airport in enumerate(airports[414:]):
#     print ( string )
    if AirportGEO.query.filter(AirportGEO.airport_id == airport.id).first():
        print("Airport", airport.code, "exists")
        pass
    else:
        print("Checking", airport.code)
        string = airport.code + " " + airport.city_name + " airport"
        g = geocoder.osm(string)
        if g.lat is None:
            string = airport.code + " airport"
            g = geocoder.osm(string)
        print("Inserting id:", airport.id, "lat:", g.lat, "lng:", g.lng)
        new_geo = AirportGEO(airport_id=airport.id, lat=g.lat, lng=g.lng)
        session.add(new_geo)
        session.commit()
# Out:
# /Users/Filip/code/python/miniconda3/envs/flaskonda/lib/python3.6/site-packages/sqlalchemy/sql/sqltypes.py:603: SAWarning: Dialect sqlite+pysqlite does *not* support Decimal objects natively, and SQLAlchemy must convert from floating point - rounding errors and other issues may occur. Please consider storing Decimal numbers as strings or integers on this platform for lossless storage.
#   'storage.' % (dialect.name, dialect.driver))
# Checking ABQ
# Inserting id: 415 lat: 35.03766945 lng: -106.610967521768
# Checking AEX
# Inserting id: 416 lat: 31.32927365 lng: -92.5409237515579
# Checking BRO
# Inserting id: 417 lat: 25.90661545 lng: -97.4254673136967
# Checking ELP
# Inserting id: 418 lat: 31.81028315 lng: -106.366552938377
# Checking LRD
# Inserting id: 419 lat: 27.5463685 lng: -99.4615285869042
# Checking MHK
# Inserting id: 420 lat: 39.13875695 lng: -96.6696133020668
# Checking BZN
# Inserting id: 421 lat: 45.78359005 lng: -111.156979627835
# Checking BUR
# Inserting id: 422 lat: 34.19629105 lng: -118.354417276818
# Checking QRO
# Inserting id: 423 lat: 20.62012845 lng: -100.18918267717
# Checking TUS
# Inserting id: 424 lat: 32.11237945 lng: -110.939387769792
# Checking SDM
# Inserting id: 425 lat: 32.57272615 lng: -116.9795567568
# Checking KHN
# Inserting id: 426 lat: 32.9816323 lng: 35.5746807364139
# Checking NGB
# Inserting id: 427 lat: 31.9873944 lng: 34.9128711
# Checking SJW
# Inserting id: 428 lat: 38.28283125 lng: 114.68856408593
# Checking WUX
# Inserting id: 429 lat: 31.49988325 lng: 120.430531377829
# Checking VIJ
# Inserting id: 430 lat: 18.4465405 lng: -64.4279041
# Checking GRR
# Inserting id: 431 lat: 42.8766147 lng: -85.5348823972425
# Checking JZQ
# Inserting id: 432 lat: None lng: None
# Checking SLW
# Inserting id: 433 lat: 25.53920895 lng: -100.931045400955
# Checking CHS
# Inserting id: 434 lat: 32.89929845 lng: -80.0394650305043
# Checking TAR
# Inserting id: 435 lat: -27.7853022 lng: 30.7875107
# Checking LAD
# Inserting id: 436 lat: -8.86146505 lng: 13.2288799767771
# Checking PSM
# Inserting id: 437 lat: 43.07777625 lng: -70.8152009942062
# Checking XCR
# Inserting id: 438 lat: 48.775763 lng: 4.19681956801625
# Checking PAE
# Inserting id: 439 lat: -2.4634732 lng: -76.9924709083073
# Checking ZAZ
# Inserting id: 440 lat: 41.6685642 lng: -1.04658295876462
# Checking MHT
# Inserting id: 441 lat: 42.93066555 lng: -71.4388276045746
# Checking SHV
# Inserting id: 442 lat: 32.4452042 lng: -93.8268695268504
# Checking TDF
# Inserting id: 443 lat: -54.3429005 lng: -67.836145
# Checking BIM
# Inserting id: 444 lat: 25.70056595 lng: -79.2722188086273
# Checking ORF
# Inserting id: 445 lat: 36.8946697 lng: -76.20229629965
# Checking MLU
# Inserting id: 446 lat: 32.5111077 lng: -92.0384615
# Checking RWI
# Inserting id: 447 lat: 35.854878 lng: -77.8927605
# Checking TMB
# Inserting id: 448 lat: 25.6477644 lng: -80.4323621
# Checking NBW
# Inserting id: 449 lat: 19.907286 lng: -75.2068874
# Checking MAJ
# Inserting id: 450 lat: 7.0678105 lng: 171.28163
# Checking PNI
# Inserting id: 451 lat: 6.9852038 lng: 158.2065127
# Checking ROR
# Inserting id: 452 lat: 7.36625725 lng: 134.533658834824
# Checking TKK
# Inserting id: 453 lat: 7.4619516 lng: 151.843053087679
# Checking VVI
# Inserting id: 454 lat: -17.65947165 lng: -63.1386222398218
# Checking IFP
# Inserting id: 455 lat: 35.15881735 lng: -114.55584530027
# Checking GOA
# Inserting id: 456 lat: 44.4127072 lng: 8.84350328561539
# Checking CRP
# Inserting id: 457 lat: 27.7702374 lng: -97.5065753547287
# Checking STI
# Inserting id: 458 lat: 17.2354048 lng: 99.8197186902712
# Checking MSN
# Inserting id: 459 lat: 43.1420815 lng: -89.3377453366062
# Checking VRA
# Inserting id: 460 lat: 23.03002255 lng: -81.4429185566935
# Checking BBU
# Inserting id: 461 lat: 44.500386 lng: 26.0904888218517
# Checking PRG
# Inserting id: 462 lat: 50.10203975 lng: 14.2705696336221
# Checking OSC
# Inserting id: 463 lat: 44.4523578 lng: -83.3880127
# Checking GSO
# Inserting id: 464 lat: 36.1031477 lng: -79.9435685047784
# Checking OCJ
# Inserting id: 465 lat: 18.4043744 lng: -76.9678927255106
# Checking SBD
# Inserting id: 466 lat: 34.09599685 lng: -117.234569101414
# Checking LAN
# Inserting id: 467 lat: 22.3161394 lng: 113.93644473373
# Checking FOE
# Inserting id: 468 lat: 38.9515803 lng: -95.6643521
# Checking SCU
# Inserting id: 469 lat: 19.9751688 lng: -75.8355631594861
# Checking LEX
# Inserting id: 470 lat: 38.03481065 lng: -84.6049234107323
# Checking YIP
# Inserting id: 471 lat: 42.2353576 lng: -83.5296148236536
# Checking SNU
# Inserting id: 472 lat: 22.4913671 lng: -79.9429718
# Checking CFB
# Inserting id: 473 lat: -22.9251764 lng: -42.0793358
# Checking BFS
# Inserting id: 474 lat: 54.6524245 lng: -6.22907615467966
# Checking HAM
# Inserting id: 475 lat: 53.63636215 lng: 9.99455013468418
# Checking APC
# Inserting id: 476 lat: 38.2126633 lng: -122.2797906
# Checking CLD
# Inserting id: 477 lat: 33.12754605 lng: -117.281400145984
# Checking FTW
# Inserting id: 478 lat: 32.8186231 lng: -97.3614385
# Checking ORH
# Inserting id: 479 lat: 42.2685519 lng: -71.8726240040542
# Checking SAV
# Inserting id: 480 lat: 32.12423765 lng: -81.1977064477445
# Checking CIA
# Inserting id: 481 lat: 41.7995615 lng: 12.5912870145685
# Checking CMW
# Inserting id: 482 lat: 21.4205221 lng: -77.8482150393818
# Checking HOG
# Inserting id: 483 lat: 20.78784055 lng: -76.320757911138
# Checking FSD
# Inserting id: 484 lat: 43.58269775 lng: -96.7412095768645
# Checking CRW
# Inserting id: 485 lat: 38.3727055 lng: -81.5942122220938
# Checking DOV
# Inserting id: 486 lat: 43.5666194 lng: 7.1016524
# Checking DSA
# Inserting id: 487 lat: 53.47641295 lng: -1.00612064592074
# Checking NGU
# Inserting id: 488 lat: 36.9375992 lng: -76.289299
# Checking MMX
# Inserting id: 489 lat: 55.5361868 lng: 13.3697156810298
# Checking GMP
# Inserting id: 490 lat: 37.55902745 lng: 126.793298543895
# Checking KWE
# Inserting id: 491 lat: 1.352516 lng: 103.986997279382
# Checking INT
# Inserting id: 492 lat: 36.1347765 lng: -80.2248745974678
# Checking BRS
# Inserting id: 493 lat: 51.38296995 lng: -2.71862377156189
# Checking CTS
# Inserting id: 494 lat: 42.79305685 lng: 141.664235933424
# Checking CMF
# Inserting id: 495 lat: 45.6352153 lng: 5.88180339311689
# Checking INL
# Inserting id: 496 lat: 48.5660857 lng: -93.404072372242
# Checking MST
# Inserting id: 497 lat: 50.91249905 lng: 5.77132050283004
# Checking ROV
# Inserting id: 498 lat: 15.3377572 lng: -61.3928993
# Checking TCB
# Inserting id: 499 lat: 10.37630815 lng: 107.096228461092
# Checking BDS
# Inserting id: 500 lat: 40.66158465 lng: 17.9486087244797
# Checking CBR
# Inserting id: 501 lat: -35.30287875 lng: 149.191800563258
# Checking CEB
# Inserting id: 502 lat: 4.0141864 lng: 9.71607499094226
# Checking MLA
# Inserting id: 503 lat: 35.8473932 lng: 14.4922673564904
# Checking POP
# Inserting id: 504 lat: 19.7573955 lng: -70.5694372312645
# Checking NYL
# Inserting id: 505 lat: 29.9692226 lng: 31.2459856490508
# Checking YYR
# Inserting id: 506 lat: 53.3187873 lng: -60.4173313419063
# Checking ACY
# Inserting id: 507 lat: 39.45708535 lng: -74.5702764909221
# Checking YXY
# Inserting id: 508 lat: 60.70919245 lng: -135.069353637564
# Checking BHM
# Inserting id: 509 lat: 33.5635078 lng: -86.7515412686466
# Checking OKC
# Inserting id: 510 lat: 35.3838245 lng: -97.6008373483474
# Checking BON
# Inserting id: 511 lat: 12.1332683 lng: -68.276866
# Checking BZE
# Inserting id: 512 lat: 17.5391371 lng: -88.3056796736267
# Checking TUL
# Inserting id: 513 lat: 36.19700895 lng: -95.8867384334883
# Checking BOM
# Inserting id: 514 lat: 19.0902005 lng: 72.863808447654
# Checking DEL
# Inserting id: 515 lat: 28.55489735 lng: 77.0846745826692
# Checking AMD
# Inserting id: 516 lat: 23.07555335 lng: 72.624267107836
# Checking YPQ
# Inserting id: 517 lat: 44.2294344 lng: -78.3672073
# Checking SLP
# Inserting id: 518 lat: 22.26100455 lng: -100.937238321128
# Checking DRW
# Inserting id: 519 lat: -12.41190185 lng: 130.883620116744
# Checking EDF
# Inserting id: 520 lat: 61.251322 lng: -149.7953931
# Checking ILN
# Inserting id: 521 lat: 39.4299546 lng: -83.7919644131912
# Checking NC1
# Inserting id: 522 lat: 1.352516 lng: 103.986997279382
# Checking RMS
# Inserting id: 523 lat: 49.44138125 lng: 7.60137004372249
# Checking WRI
# Inserting id: 524 lat: None lng: None
# Checking MHZ
# Inserting id: 525 lat: 52.3629101 lng: 0.484797573869427
# Checking N2C
# Inserting id: 526 lat: None lng: None
# Checking PDK
# Inserting id: 527 lat: 33.8759268 lng: -84.3028446859301
# Checking QMA
# Inserting id: 528 lat: None lng: None
# Checking COR
# Inserting id: 529 lat: -31.30197195 lng: -64.2125938141194
# Checking COS
# Inserting id: 530 lat: 38.8031838 lng: -104.699753533694
# Checking CRK
# Inserting id: 531 lat: 22.3161394 lng: 113.93644473373
# Checking CHD
# Inserting id: 532 lat: 33.26982465 lng: -111.810925305782
# Checking ALB
# Inserting id: 533 lat: 42.74801595 lng: -73.7985556376393
# Checking ADD
# Inserting id: 534 lat: 8.9793576 lng: 38.7965943182587
# Checking BHX
# Inserting id: 535 lat: 52.45417725 lng: -1.7438763476787
# Checking AUH
# Inserting id: 536 lat: 24.4393782 lng: 54.6539986
# Checking CAI
# Inserting id: 537 lat: 29.9692226 lng: 31.2459856490508
# Checking BJL
# Inserting id: 538 lat: 13.33633215 lng: -16.6494823020971
# Checking DAY
# Inserting id: 539 lat: 39.9053187 lng: -84.2202454248027
# Checking ANB
# Inserting id: 540 lat: 33.5881641 lng: -85.8581158
# Checking ABE
# Inserting id: 541 lat: 40.6511631 lng: -75.442253868383
# Checking BIF
# Inserting id: 542 lat: 31.8341577 lng: -106.3899642
# Checking DWC
# Inserting id: 543 lat: 24.8926515 lng: 55.1639079450187
# Checking DAC
# Inserting id: 544 lat: 23.8462861 lng: 90.40215
# Checking ATH
# Inserting id: 545 lat: 37.93732705 lng: 23.9465284918041
# Checking AGS
# Inserting id: 546 lat: 33.37230205 lng: -81.9650639098103
# Checking GHB
# Inserting id: 547 lat: 25.2840555 lng: -76.3300040584771
# Checking YTZ
# Inserting id: 548 lat: 43.62805705 lng: -79.3979911558998
# Checking VQS
# Inserting id: 549 lat: 18.13462385 lng: -65.49260790791
# Checking SIG
# Inserting id: 550 lat: 18.4564326 lng: -66.100336566256
# Checking NGD
# Inserting id: 551 lat: 18.7275409 lng: -64.329337339391
# Checking UNI
# Inserting id: 552 lat: 39.2120408 lng: -82.2271944826597
# Checking BTV
# Inserting id: 553 lat: 44.4728965 lng: -73.1514631075075
# Checking PGA
# Inserting id: 554 lat: 36.9265975 lng: -111.448471748077
# Checking CXH
# Inserting id: 555 lat: 49.29075025 lng: -123.118267964996
# Checking KEH
# Inserting id: 556 lat: 47.75719295 lng: -122.257787151981
# Checking LKE
# Inserting id: 557 lat: 47.6283963 lng: -122.3386993
# Checking FBS
# Inserting id: 558 lat: 48.5379087 lng: -123.0135138
# Checking YWH
# Inserting id: 559 lat: 48.4253301 lng: -123.3904221
# Checking YGG
# Inserting id: 560 lat: 48.8544222 lng: -123.4970719
# Checking PBC
# Inserting id: 561 lat: 50.2380447 lng: 19.0337927579138
# Checking FDH
# Inserting id: 562 lat: 47.6711274 lng: 9.51098121192751
# Checking CEQ
# Inserting id: 563 lat: 43.5479587 lng: 6.95981340136274
# Checking ACA
# Inserting id: 564 lat: 16.7599412 lng: -99.7545988
# Checking NAP
# Inserting id: 565 lat: 40.8838572 lng: 14.2845432257409
# Checking PMO
# Inserting id: 566 lat: 38.1765127 lng: 13.091635353863
# Checking TPS
# Inserting id: 567 lat: 37.91300895 lng: 12.4926218620411
# Checking CHR
# Inserting id: 568 lat: 46.8645394 lng: 1.73154081881467
# Checking MYR
# Inserting id: 569 lat: 33.6806406 lng: -78.9290597087289
# Checking LTO
# Inserting id: 570 lat: 14.501616 lng: 120.9998494
# Checking PVU
# Inserting id: 571 lat: 40.2204 lng: -111.720972296685
# Checking TLH
# Inserting id: 572 lat: 30.40016355 lng: -84.3570087255944
# Checking RTB
# Inserting id: 573 lat: 16.3169504 lng: -86.5248059338583
# Checking EDI
# Inserting id: 574 lat: 55.95012215 lng: -3.3594790803642
# Checking NGS
# Inserting id: 575 lat: 32.917846 lng: 129.915337535379
# Checking BLV
# Inserting id: 576 lat: 39.8162411 lng: -97.6594831
# Checking CAY
# Inserting id: 577 lat: 4.8210723 lng: -52.3608812606252
# Checking RIC
# Inserting id: 578 lat: 37.5066992 lng: -77.3216007712537
# Checking BIO
# Inserting id: 579 lat: 43.30184055 lng: -2.917856205337
# Checking RKE
# Inserting id: 580 lat: 55.58567075 lng: 12.1329821693875
# Checking UUS
# Inserting id: 581 lat: 46.8854696 lng: 142.719917888397
# Checking OLB
# Inserting id: 582 lat: 40.89937665 lng: 9.51774548429487
# Checking LDE
# Inserting id: 583 lat: 43.17976295 lng: -0.000100923887124385
# Checking BCT
# Inserting id: 584 lat: 26.3785634 lng: -80.1084333727273
# Checking DSM
# Inserting id: 585 lat: 41.534256 lng: -93.6592718234974
# Checking SMB
# Inserting id: 586 lat: 37.1464789 lng: -94.3114022869427
# Checking EKI
# Inserting id: 587 lat: 41.71710445 lng: -85.9948243046813
# Checking ICT
# Inserting id: 588 lat: 37.649253 lng: -97.432263303093
# Checking MLB
# Inserting id: 589 lat: 28.1027201 lng: -80.648158012358
# Checking OCA
# Inserting id: 590 lat: 25.3229581 lng: -80.276666
# Checking OTH
# Inserting id: 591 lat: 43.41571585 lng: -124.245326678455
# Checking SUA
# Inserting id: 592 lat: 36.7355861 lng: -80.4506264
# Checking YTM
# Inserting id: 593 lat: 46.4071076 lng: -74.7793708
# Checking YKZ
# Inserting id: 594 lat: 43.86122555 lng: -79.3697267166076
# Checking YLS
# Inserting id: 595 lat: 49.02990215 lng: -77.0165279041986
# Checking PAD
# Inserting id: 596 lat: 51.61438565 lng: 8.61859130430152
# Checking VLC
# Inserting id: 597 lat: 39.4878647 lng: -0.481209186098332
# Checking AGT
# Inserting id: 598 lat: 47.96416235 lng: 16.2596431583768
# Checking BKL
# Inserting id: 599 lat: 41.5188169 lng: -81.6811324115242
# Checking MFE
# Inserting id: 600 lat: 26.17628335 lng: -98.2395985920612
# Checking CXO
# Inserting id: 601 lat: 30.3551148 lng: -95.4178459948305
# Checking LBV
# Inserting id: 602 lat: 0.46203635 lng: 9.41139256134668
# Checking PWM
# Inserting id: 603 lat: 43.6461777 lng: -70.3144195636337
# Checking LUG
# Inserting id: 604 lat: 48.9015466 lng: 38.5418547345215
# Checking CKG
# Inserting id: 605 lat: 29.7261592 lng: 106.649836427908
# Checking CTU
# Inserting id: 606 lat: 30.5540115 lng: 103.954867097677
# Checking CWL
# Inserting id: 607 lat: 51.39782775 lng: -3.34456993560398
# Checking OAX
# Inserting id: 608 lat: 15.7743841 lng: -96.2604
# Checking JBQ
# Inserting id: 609 lat: 18.5713733 lng: -69.9859552449411
# Checking LSP
# Inserting id: 610 lat: 11.7788198 lng: -70.1490194
# Checking MDZ
# Inserting id: 611 lat: -32.82749405 lng: -68.7947245899313
# Checking SGN
# Inserting id: 612 lat: 10.81831885 lng: 106.65812173979
# Checking WFB
# Inserting id: 613 lat: 55.3457782 lng: -131.6642014
# Checking ZSW
# Inserting id: 614 lat: 54.3312433 lng: -130.2819534
# Checking FOC
# Inserting id: 615 lat: 25.93509645 lng: 119.666656068362
# Checking SZX
# Inserting id: 616 lat: 22.6375876 lng: 113.806116887602
# Checking XMN
# Inserting id: 617 lat: 24.5444158 lng: 118.133740765925
# Checking BMA
# Inserting id: 618 lat: 59.3546192 lng: 17.944740459282
# Checking SIR
# Inserting id: 619 lat: 41.08372595 lng: 23.587897790167
# Checking GRB
# Inserting id: 620 lat: 44.4800791 lng: -88.1373511303285
# Checking ZSA
# Inserting id: 621 lat: 24.06408745 lng: -74.531066302619
# Checking SGR
# Inserting id: 622 lat: 29.6257202 lng: -95.6552509
# Checking NTR
# Inserting id: 623 lat: 25.86668535 lng: -100.240805197311
# Checking TRN
# Inserting id: 624 lat: 45.20208785 lng: 7.64901337404513
# Checking DET
# Inserting id: 625 lat: 42.4102292 lng: -83.0073545304566
# Checking DBV
# Inserting id: 626 lat: 49.6108071 lng: 10.2227152955873
# Checking NEW
# Inserting id: 627 lat: 30.0419 lng: -90.0281
# Checking RDG
# Inserting id: 628 lat: 40.3781706 lng: -75.9666830412704
# Checking LFT
# Inserting id: 629 lat: 30.2031617 lng: -91.9899106562818
# Checking CAE
# Inserting id: 630 lat: 49.8333015 lng: -114.8830032
# Checking CJU
# Inserting id: 631 lat: 33.50670395 lng: 126.491648871747
# Checking EIL
# Inserting id: 632 lat: 64.6644444 lng: -147.0994444
# Checking HMY
# Inserting id: 633 lat: None lng: None
# Checking VIE
# Inserting id: 634 lat: 37.20528 lng: -80.40851
# Checking KNA
# Inserting id: 635 lat: -32.9489835 lng: -71.4791867
# Checking ANR
# Inserting id: 636 lat: 51.18812585 lng: 4.46350262675845
# Checking BDR
# Inserting id: 637 lat: 41.1636285 lng: -73.125760158787
# Checking YQA
# Inserting id: 638 lat: 44.9754065 lng: -79.3067403537869
# Checking BIS
# Inserting id: 639 lat: 46.7732585 lng: -100.747163666215
# Checking CAK
# Inserting id: 640 lat: 40.91522255 lng: -81.4399157903413
# Checking CHA
# Inserting id: 641 lat: 35.03241695 lng: -85.2016830972987
# Checking IAG
# Inserting id: 642 lat: 43.1074871 lng: -78.950867676264
# Checking PAH
# Inserting id: 643 lat: 37.0596 lng: -88.773
# Checking SCE
# Inserting id: 644 lat: 40.850333 lng: -77.8486476120945
# Checking YSN
# Inserting id: 645 lat: 50.6828003 lng: -119.2289963
# Checking YSU
# Inserting id: 646 lat: 46.4406013 lng: -63.8335991
# Checking FCA
# Inserting id: 647 lat: 48.3108042 lng: -114.255693734217
# Checking ATW
# Inserting id: 648 lat: 44.2573941 lng: -88.5168844733873
# Checking JAC
# Inserting id: 649 lat: 43.6087926 lng: -110.738032484948
# Checking JNU
# Inserting id: 650 lat: 58.3558678 lng: -134.579793165695
# Checking MSO
# Inserting id: 651 lat: 46.91686665 lng: -114.087800538914
# Checking SBA
# Inserting id: 652 lat: 34.425792 lng: -119.846103916591
# Checking YKM
# Inserting id: 653 lat: 46.56681015 lng: -120.53679819122
# Checking MWH
# Inserting id: 654 lat: 47.2054452 lng: -119.315467250581
# Checking DAV
# Inserting id: 655 lat: 8.3913324 lng: -82.4320368
# Checking CGI
# Inserting id: 656 lat: 37.2251275 lng: -89.5687508
# Checking ISM
# Inserting id: 657 lat: 28.2903286 lng: -81.4367788
# Checking MKC
# Inserting id: 658 lat: 39.12417015 lng: -94.5928393404876
# Checking SPS
# Inserting id: 659 lat: 33.9903039 lng: -98.4949199
# Checking MOB
# Inserting id: 660 lat: 30.69214065 lng: -88.2411574906623
# Checking VER
# Inserting id: 661 lat: 19.14114965 lng: -96.1823649706986
# Checking CFG
# Inserting id: 662 lat: 9.6650903 lng: 123.853614864666
# Checking EYW
# Inserting id: 663 lat: 24.5554773 lng: -81.7596160347508
# Checking AST
# Inserting id: 664 lat: 46.15635245 lng: -123.88297555618
# Checking EUG
# Inserting id: 665 lat: 44.12052185 lng: -123.213890965643
# Checking SUN
# Inserting id: 666 lat: 43.50392605 lng: -114.297154199526
# Checking TBU
# Inserting id: 667 lat: -21.2421737 lng: -175.144364683086
# Checking DQN
# Inserting id: 668 lat: None lng: None
# Checking DPA
# Inserting id: 669 lat: 41.90533745 lng: -88.2521057755476
# Checking HYA
# Inserting id: 670 lat: 41.6707658 lng: -70.2848196585386
# Checking YCL
# Inserting id: 671 lat: 47.990799 lng: -66.3302994
# Checking LBE
# Inserting id: 672 lat: 40.2729348 lng: -79.406419571798
# Checking AVN
# Inserting id: 673 lat: 43.9063559 lng: 4.90201640965467
# Checking MLH
# Inserting id: 674 lat: 47.60323695 lng: 7.52434812773247
# Checking YVB
# Inserting id: 675 lat: 48.07118955 lng: -65.460218460148
# Checking AMA
# Inserting id: 676 lat: 35.21937225 lng: -101.701847226279
# Checking QPG
# Inserting id: 677 lat: None lng: None
# Checking CN2
# Inserting id: 678 lat: None lng: None
# Checking ZNA
# Inserting id: 679 lat: 49.1698302 lng: -123.9351766
# Checking LPS
# Inserting id: 680 lat: 48.4845639 lng: -122.9374729
# Checking RCE
# Inserting id: 681 lat: 48.6081548 lng: -123.1596319
# Checking RSJ
# Inserting id: 682 lat: 48.6461518 lng: -122.8696614
# Checking YMP
# Inserting id: 683 lat: 50.57581075 lng: -127.031100640073
# Checking YPT
# Inserting id: 684 lat: 49.6319343 lng: -124.0425407
# Checking YTP
# Inserting id: 685 lat: 49.1548922 lng: -125.9056251
# Checking BC5
# Inserting id: 686 lat: None lng: None
# Checking BC7
# Inserting id: 687 lat: None lng: None
# Checking BC9
# Inserting id: 688 lat: None lng: None
# Checking YBL
# Inserting id: 689 lat: 49.9540995 lng: -125.275718067915
# Checking FRD
# Inserting id: 690 lat: 48.5236309 lng: -123.025106158084
# Checking YAZ
# Inserting id: 691 lat: 49.08161545 lng: -125.779320691076
# Checking YDS
# Inserting id: 692 lat: None lng: None
# Checking YHH
# Inserting id: 693 lat: 50.0464809 lng: -125.2555537
# Checking YHS
# Inserting id: 694 lat: 49.4602145 lng: -123.71702618874
# Checking YQJ
# Inserting id: 695 lat: None lng: None
# Checking YR1
# Inserting id: 696 lat: None lng: None
# Checking PSE
# Inserting id: 697 lat: 18.008886 lng: -66.5633497464292
# Checking KWA
# Inserting id: 698 lat: 5.6008901 lng: -0.177062
# Checking TGU
# Inserting id: 699 lat: 14.05946375 lng: -87.2172811551739
# Checking AFW
# Inserting id: 700 lat: 32.9905456 lng: -97.3188967968959
# Checking TRC
# Inserting id: 701 lat: 44.02021415 lng: 12.6125905431537
# Checking TOL
# Inserting id: 702 lat: 41.58738615 lng: -83.8108157618756
# Checking LCH
# Inserting id: 703 lat: 30.1279008 lng: -93.2245961
# Checking JRV
# Inserting id: 704 lat: None lng: None
# Checking YQT
# Inserting id: 705 lat: 48.37209765 lng: -89.3272583216942
# Checking PMI
# Inserting id: 706 lat: 39.55231285 lng: 2.72832122305246
# Checking YHD
# Inserting id: 707 lat: 49.8305954 lng: -92.7454401
# Checking FTY
# Inserting id: 708 lat: 33.7789954 lng: -84.5213205
# Checking GON
# Inserting id: 709 lat: 41.33232565 lng: -72.0404429432381
# Checking BAH
# Inserting id: 710 lat: 26.27017855 lng: 50.6303427381967
# Checking QQY
# Inserting id: 711 lat: None lng: None
# Checking DYR
# Inserting id: 712 lat: 64.7367758 lng: 177.736699761432
# Checking OME
# Inserting id: 713 lat: 64.5123545 lng: -165.455283998269
# Checking PVS
# Inserting id: 714 lat: 64.38003795 lng: -173.237470127825
# Checking SKF
# Inserting id: 715 lat: 29.3838847 lng: -98.5861854258543
# Checking CGQ
# Inserting id: 716 lat: 43.9960728 lng: 125.686563502653
# Checking VCE
# Inserting id: 717 lat: 45.50353855 lng: 12.3425796810648
# Checking B4C
# Inserting id: 718 lat: -33.6677644 lng: 150.3227069
# Checking CA9
# Inserting id: 719 lat: 14.5832447 lng: -90.5271747759008
# Checking ESD
# Inserting id: 720 lat: 48.70740765 lng: -122.91076224899
# Checking ZEL
# Inserting id: 721 lat: 52.1851176 lng: -128.1568547
# Checking BRI
# Inserting id: 722 lat: 22.3161394 lng: 113.93644473373
# Checking TLN
# Inserting id: 723 lat: 43.09576915 lng: 6.14784637673918
# Checking DNR
# Inserting id: 724 lat: 48.58873 lng: -2.08109393788802
# Checking ACK
# Inserting id: 725 lat: 41.25579665 lng: -70.058035942437
# Checking AVL
# Inserting id: 726 lat: 35.4364104 lng: -82.5403194139771
# Checking FNL
# Inserting id: 727 lat: 40.4509274 lng: -105.0106151
# Checking YND
# Inserting id: 728 lat: 45.5209027 lng: -75.564680130971
# Checking HSH
# Inserting id: 729 lat: 35.97313425 lng: -115.136075636094
# Checking ISW
# Inserting id: 730 lat: 44.36169675 lng: -89.8368602124817
# Checking MBL
# Inserting id: 731 lat: 44.2717152 lng: -86.2406121769047
# Checking YCK
# Inserting id: 732 lat: 67.0226918 lng: -126.1250358
# Checking MSV
# Inserting id: 733 lat: 41.70198565 lng: -74.7966660658213
# Checking YQL
# Inserting id: 734 lat: 49.629112 lng: -112.790928586084
# Checking ORL
# Inserting id: 735 lat: 28.54617435 lng: -81.3316359131412
# Checking RNH
# Inserting id: 736 lat: 45.1476439 lng: -92.534927044403
# Checking TRI
# Inserting id: 737 lat: 36.47345205 lng: -82.4084425677972
# Checking VWK
# Inserting id: 738 lat: None lng: None
# Checking MBS
# Inserting id: 739 lat: 43.53579615 lng: -84.0828495668065
# Checking YGE
# Inserting id: 740 lat: 50.0990867 lng: -125.0236065
# Checking ERI
# Inserting id: 741 lat: 42.08483935 lng: -80.174167928349
# Checking INN
# Inserting id: 742 lat: 47.2597258 lng: 11.341870475
# Checking LBC
# Inserting id: 743 lat: 11.216594 lng: 124.9957647
# Checking LBF
# Inserting id: 744 lat: 41.1238874 lng: -100.6769689
# Checking PUB
# Inserting id: 745 lat: 38.29844685 lng: -104.503307959449
# Checking ZAG
# Inserting id: 746 lat: 45.74027185 lng: 16.0723161609809
# Checking POM
# Inserting id: 747 lat: -9.44025935 lng: 147.217122824251
# Checking VCV
# Inserting id: 748 lat: 34.5954562 lng: -117.3822518
# Checking CYS
# Inserting id: 749 lat: 41.1562943 lng: -104.808824619265
# Checking SLU
# Inserting id: 750 lat: 14.0199457 lng: -60.9945210892928
# Checking AJA
# Inserting id: 751 lat: 41.9215216 lng: 8.79991726962609
# Checking BIQ
# Inserting id: 752 lat: 43.46909385 lng: -1.52287117396161
# Checking MTN
# Inserting id: 753 lat: 39.3245375 lng: -76.4148299439755
# Checking SFJ
# Inserting id: 754 lat: 67.0113433 lng: -50.7074265016447
# Checking YUX
# Inserting id: 755 lat: 68.7761002 lng: -81.2435989
# Checking YPD
# Inserting id: 756 lat: 45.25985195 lng: -79.8309528304044
# Checking TN8
# Inserting id: 757 lat: 36.1463977 lng: -86.6626875
# Checking TNG
# Inserting id: 758 lat: 35.72919815 lng: -5.91297190088664
# Checking BGO
# Inserting id: 759 lat: 60.29610135 lng: 5.22338175445166
# Checking ORK
# Inserting id: 760 lat: 51.8489149 lng: -8.48993708163901
# Checking KMQ
# Inserting id: 761 lat: 36.3931775 lng: 136.408011
# Checking SDJ
# Inserting id: 762 lat: 38.137423 lng: 140.921352123681
# Checking SUU
# Inserting id: 763 lat: 38.263 lng: -121.9278
# Checking LSV
# Inserting id: 764 lat: 36.2374797 lng: -115.032206985162
# Checking NKX
# Inserting id: 765 lat: 32.8763782 lng: -117.082490564366
# Checking IDA
# Inserting id: 766 lat: 43.5151828 lng: -112.066210518897
# Checking YXC
# Inserting id: 767 lat: 49.6121312 lng: -115.783828339306
# Checking CDB
# Inserting id: 768 lat: 55.1992323 lng: -162.7200372
# Checking RAK
# Inserting id: 769 lat: 35.3078099 lng: -92.320215
# Checking YSJ
# Inserting id: 770 lat: 45.3138738 lng: -65.8858644023684
# Checking PMV
# Inserting id: 771 lat: -20.25569105 lng: -40.2817734219972
# Checking PUL
# Inserting id: 772 lat: 47.7341171 lng: -122.6480849
# Checking RNT
# Inserting id: 773 lat: 47.4926286 lng: -122.2149159
# Checking SMA
# Inserting id: 774 lat: 36.97192525 lng: -25.1688280708836
# Checking ADL
# Inserting id: 775 lat: -34.94724045 lng: 138.533070100537
# Checking GML
# Inserting id: 776 lat: 52.5264191 lng: 31.0182677728879
# Checking ABZ
# Inserting id: 777 lat: 57.20195485 lng: -2.20198146926634
# Checking ERF
# Inserting id: 778 lat: 50.9792725 lng: 10.9586466200839
# Checking HRL
# Inserting id: 779 lat: 26.23111485 lng: -97.6534846439368
# Checking ADS
# Inserting id: 780 lat: 32.9699986 lng: -96.8366773931934
# Checking GFK
# Inserting id: 781 lat: 47.9518219 lng: -97.174470652996
# Checking YJT
# Inserting id: 782 lat: 48.5442009 lng: -58.5499992
# Checking KUL
# Inserting id: 783 lat: 2.74552395 lng: 101.701506799265
# Checking HIO
# Inserting id: 784 lat: 45.54171585 lng: -122.947490464957
# Checking PGV
# Inserting id: 785 lat: 35.63797635 lng: -77.3800183967476
# Checking BSL
# Inserting id: 786 lat: 47.60323695 lng: 7.52434812773247
# Checking TSV
# Inserting id: 787 lat: -19.24597335 lng: 146.763618764623
# Checking CIX
# Inserting id: 788 lat: -6.7890129 lng: -79.8270841199276
# Checking VVO
# Inserting id: 789 lat: 43.39209495 lng: 132.146861739787
# Checking IBZ
# Inserting id: 790 lat: 38.87294765 lng: 1.37037543549875
# Checking INV
# Inserting id: 791 lat: 57.54227005 lng: -4.05167128266887
# Checking CID
# Inserting id: 792 lat: 41.8851038 lng: -91.7147100196582
# Checking DSI
# Inserting id: 793 lat: 30.3997194 lng: -86.4705373409189
# Checking FMY
# Inserting id: 794 lat: 26.58587405 lng: -81.862081160201
# Checking NC8
# Inserting id: 795 lat: None lng: None
# Checking WLG
# Inserting id: 796 lat: -41.32691975 lng: 174.807702963453
# Checking SSA
# Inserting id: 797 lat: -13.0063024 lng: -38.5090577
# Checking DWH
# Inserting id: 798 lat: 30.0612061 lng: -95.5535957800425
# Checking VQQ
# Inserting id: 799 lat: 30.21743295 lng: -81.8801120769355
# Checking HAN
# Inserting id: 800 lat: 21.043277 lng: 105.890775157347
# Checking WMI
# Inserting id: 801 lat: 52.45088565 lng: 20.6489881176213
# Checking VRN
# Inserting id: 802 lat: 49.4748305 lng: 8.51625942177832
# Checking DOL
# Inserting id: 803 lat: 49.3655447 lng: 0.155342536152169
# Checking PNH
# Inserting id: 804 lat: 11.54653 lng: 104.848021604407
# Checking OGD
# Inserting id: 805 lat: 41.19456325 lng: -112.013519624439
# Checking OBF
# Inserting id: 806 lat: 48.0835074 lng: 11.2889992433827
# Checking PMC
# Inserting id: 807 lat: -41.4435617 lng: -73.0945245319257
# Checking DMA
# Inserting id: 808 lat: 32.17079565 lng: -110.869902396303
# Checking OST
# Inserting id: 809 lat: 38.12092225 lng: 46.2426043025877
# Checking EBB
# Inserting id: 810 lat: 0.0448664 lng: 32.4417503
# Checking STC
# Inserting id: 811 lat: 45.54617645 lng: -94.0584544502723
# Checking YAM
# Inserting id: 812 lat: 46.4850006 lng: -84.5093994
# Checking YSB
# Inserting id: 813 lat: 46.625 lng: -80.7988968
# Checking SSM
# Inserting id: 814 lat: 12.90391155 lng: 80.1204259958211
# Checking LIT
# Inserting id: 815 lat: 34.7311092 lng: -92.2245781780175
# Checking ITH
# Inserting id: 816 lat: 42.491 lng: -76.4587
# Checking MOT
# Inserting id: 817 lat: 48.25794645 lng: -101.277005043469
# Checking VRB
# Inserting id: 818 lat: 27.65721495 lng: -80.4183298044314
# Checking TUC
# Inserting id: 819 lat: -26.8391119 lng: -65.1080126224558
# Checking MAR
# Inserting id: 820 lat: 56.705172 lng: 47.8959189090629
# Checking GHC
# Inserting id: 821 lat: -29.99535095 lng: -51.1673943208504
# Checking EVV
# Inserting id: 822 lat: 38.03988835 lng: -87.527821234368
# Checking PSC
# Inserting id: 823 lat: 46.26395235 lng: -119.113036872055
# Checking KSA
# Inserting id: 824 lat: 22.98738085 lng: -82.4142380143921
# Checking SVG
# Inserting id: 825 lat: 58.8808874 lng: 5.62544699635504
# Checking BIL
# Inserting id: 826 lat: 45.80923485 lng: -108.547675178859
# Checking RUT
# Inserting id: 827 lat: 43.53170155 lng: -72.9506293842989
# Checking YUM
# Inserting id: 828 lat: 32.64851395 lng: -114.607725868737
# Checking CNS
# Inserting id: 829 lat: -16.87811375 lng: 145.751753619789
# Checking DNA
# Inserting id: 830 lat: 26.3555999 lng: 127.7675
# Checking ZXA
# Inserting id: 831 lat: None lng: None
# Checking OKO
# Inserting id: 832 lat: 35.7490925 lng: 139.3490931
# Checking HIK
# Inserting id: 833 lat: 21.3330347 lng: -157.95176433583
# Checking OSN
# Inserting id: 834 lat: 37.0897998 lng: 127.0297346
# Checking RJK
# Inserting id: 835 lat: 10.5968385 lng: -61.3378286127359
# Checking UAM
# Inserting id: 836 lat: 13.5811111 lng: 144.9244444
# Checking XMR
# Inserting id: 837 lat: None lng: None
# Checking HIJ
# Inserting id: 838 lat: 34.4374791 lng: 132.919514817226
# Checking IWA
# Inserting id: 839 lat: 56.9413672 lng: 40.9377329934159
# Checking PRC
# Inserting id: 840 lat: 34.6553753 lng: -112.418438077962
# Checking VIT
# Inserting id: 841 lat: 42.88306505 lng: -2.72804383880985
# Checking BVB
# Inserting id: 842 lat: 2.84885365 lng: -60.6808710889154
# Checking NCO
# Inserting id: 843 lat: 41.6012186 lng: -71.4114157915918
# Checking OQU
# Inserting id: 844 lat: 1.661822 lng: 7.4117221
# Checking USA
# Inserting id: 845 lat: 35.391172 lng: -80.525129
# Checking SSB
# Inserting id: 846 lat: -28.6523732 lng: -56.0302822892094
# Checking PKC
# Inserting id: 847 lat: 53.1707014 lng: 158.441697315676
# Checking BOJ
# Inserting id: 848 lat: 42.5686628 lng: 27.5154115
# Checking TIX
# Inserting id: 849 lat: 28.5142066 lng: -80.7990149
# Checking SZG
# Inserting id: 850 lat: 47.79346125 lng: 13.0018170077651
# Checking BEY
# Inserting id: 851 lat: 33.8187787 lng: 35.4912054168716
# Checking CHC
# Inserting id: 852 lat: 22.3161394 lng: 113.93644473373
# Checking HAJ
# Inserting id: 853 lat: 52.46144075 lng: 9.68723657582659
# Checking NIM
# Inserting id: 854 lat: 22.3158213 lng: 113.9366406
# Checking RKD
# Inserting id: 855 lat: 44.059992 lng: -69.098376
# Checking AER
# Inserting id: 856 lat: 34.8871048 lng: -91.1777274
# Checking ZXD
# Inserting id: 857 lat: None lng: None
# Checking GDT
# Inserting id: 858 lat: 21.44465585 lng: -71.1438316409642
# Checking EFK
# Inserting id: 859 lat: 44.8883815 lng: -72.2285615375508
# Checking RMI
# Inserting id: 860 lat: 44.02021415 lng: 12.6125905431537
# Checking HTS
# Inserting id: 861 lat: 38.36709 lng: -82.5554967862635
# Checking VLD
# Inserting id: 862 lat: 30.7825 lng: -83.2766
# Checking UGN
# Inserting id: 863 lat: 42.42100275 lng: -87.8674836703092
# Checking STS
# Inserting id: 864 lat: 38.50917815 lng: -122.814813690718
# Checking YYB
# Inserting id: 865 lat: 46.3639218 lng: -79.4167541553211
# Checking YFC
# Inserting id: 866 lat: 45.87009425 lng: -66.5339273099822
# Checking YPS
# Inserting id: 867 lat: 45.65680205 lng: -61.3679371135268
# Checking KIR
# Inserting id: 868 lat: -3.42787345 lng: 37.0762665438529
# Checking ROA
# Inserting id: 869 lat: 37.32442615 lng: -79.9767941645411
# Checking FNT
# Inserting id: 870 lat: 42.9607553 lng: -83.745631779992
# Checking OLS
# Inserting id: 871 lat: 31.4178318 lng: -110.848094691298
# Checking PHF
# Inserting id: 872 lat: 37.1319469 lng: -76.4942203814681
# Checking YML
# Inserting id: 873 lat: 47.5976629 lng: -70.2259158
# Checking XIY
# Inserting id: 874 lat: 34.43872725 lng: 108.758010874322
# Checking CLM
# Inserting id: 875 lat: 48.12098895 lng: -123.504826589383
# Checking PIA
# Inserting id: 876 lat: 40.66385275 lng: -89.690728807529
# Checking GRS
# Inserting id: 877 lat: 42.76071625 lng: 11.0713394546827
# Checking EAS
# Inserting id: 878 lat: 43.3566134 lng: -1.7918916216553
# Checking VNO
# Inserting id: 879 lat: 54.63483615 lng: 25.2903143304395
# Checking SCK
# Inserting id: 880 lat: 37.89246385 lng: -121.237589812721
# Checking NIP
# Inserting id: 881 lat: 30.23218005 lng: -81.6791935827137
# Checking NUW
# Inserting id: 882 lat: None lng: None
# Checking ORG
# Inserting id: 883 lat: 5.81120505 lng: -55.1925296362282
# Checking CRQ
# Inserting id: 884 lat: -17.65213575 lng: -39.2523210855175
# Checking PRB
# Inserting id: 885 lat: 35.6759425 lng: -120.630717216396
# Checking SBP
# Inserting id: 886 lat: 35.23745155 lng: -120.643307881982
# Checking DRT
# Inserting id: 887 lat: 29.3725627 lng: -100.922483226475
# Checking LOS
# Inserting id: 888 lat: 22.3161394 lng: 113.93644473373
# Checking YZT
# Inserting id: 889 lat: 50.68186165 lng: -127.369770082381
# Checking BYW
# Inserting id: 890 lat: 48.57932825 lng: -122.8252513225
# Checking WSX
# Inserting id: 891 lat: 48.6288403 lng: -122.9569621
# Checking ABV
# Inserting id: 892 lat: 9.00706695 lng: 7.26514987293491
# Checking TIK
# Inserting id: 893 lat: None lng: None
# Checking SSC
# Inserting id: 894 lat: 33.9726982 lng: -80.4705963
# Checking ASD
# Inserting id: 895 lat: 24.6984596 lng: -77.8000218292017
# Checking FSZ
# Inserting id: 896 lat: 34.7965038 lng: 138.184137072165
# Checking KIV
# Inserting id: 897 lat: 50.4068453 lng: 30.4455115281123
# Checking TRU
# Inserting id: 898 lat: -8.080591 lng: -79.1084100552549
# Checking CMI
# Inserting id: 899 lat: 40.0373168 lng: -88.2716729827622
# Checking DSS
# Inserting id: 900 lat: -2.15634455 lng: -79.8845896020962
# Checking TAM
# Inserting id: 901 lat: 22.29084975 lng: -97.8651927836165
# Checking RGN
# Inserting id: 902 lat: 16.9107155 lng: 96.1373654058674
# Checking JZT
# Inserting id: 903 lat: None lng: None
# Checking SUS
# Inserting id: 904 lat: 38.6625335 lng: -90.6459449086526
# Checking ZBF
# Inserting id: 905 lat: 47.6296997 lng: -65.7388992
# Checking GOT
# Inserting id: 906 lat: 57.66241475 lng: 12.2877630012367
# Checking VBG
# Inserting id: 907 lat: 34.73835455 lng: -120.5826245702
# Checking NOU
# Inserting id: 908 lat: 46.61541405 lng: 5.35266714260175
# Checking TOJ
# Inserting id: 909 lat: 40.48925075 lng: -3.43729321933048
# Checking ENV
# Inserting id: 910 lat: 40.727169 lng: -114.0389708
# Checking FVT
# Inserting id: 911 lat: None lng: None
# Checking BFM
# Inserting id: 912 lat: 30.62555175 lng: -88.0696530005236
# Checking KKJ
# Inserting id: 913 lat: 33.8417041 lng: 131.034752
# Checking KIJ
# Inserting id: 914 lat: 37.9555294 lng: 139.118527
# Checking ECI
# Inserting id: 915 lat: 11.4307121 lng: -86.031327203629
# Checking ROB
# Inserting id: 916 lat: 6.23262 lng: -10.362399893226
# Checking NPE
# Inserting id: 917 lat: -39.4665174 lng: 176.871980963092
# Checking YQU
# Inserting id: 918 lat: 55.1800502 lng: -118.878292425329
# Checking MGM
# Inserting id: 919 lat: 32.2967059 lng: -86.390385251668
# Checking ECP
# Inserting id: 920 lat: 30.36049315 lng: -85.796507218057
# Checking PNS
# Inserting id: 921 lat: 30.4725975 lng: -87.188085929191
# Checking CVJ
# Inserting id: 922 lat: 18.8329722 lng: -99.2606796
# Checking IWK
# Inserting id: 923 lat: 51.72388565 lng: 11.9514257027675
# Checking OZP
# Inserting id: 924 lat: 37.1734006 lng: -5.6165959
# Checking LKZ
# Inserting id: 925 lat: 52.4050646 lng: 0.556529150920792
# Checking YQQ
# Inserting id: 926 lat: 49.7066374 lng: -124.9077184
# Checking TEX
# Inserting id: 927 lat: 31.3620895 lng: -100.4943039
# Checking TVL
# Inserting id: 928 lat: 38.89458785 lng: -119.996017738823
# Checking OKJ
# Inserting id: 929 lat: 34.7569745 lng: 133.853867415041
# Checking BQK
# Inserting id: 930 lat: 31.259811 lng: -81.4639706620112
# Checking SLM
# Inserting id: 931 lat: 40.9510067 lng: -5.50164020305584
# Checking GPT
# Inserting id: 932 lat: 22.3161394 lng: 113.93644473373
# Checking TFS
# Inserting id: 933 lat: 28.04605465 lng: -16.5727152996735
# Checking PKB
# Inserting id: 934 lat: 39.3434644 lng: -81.4401026346384
# Checking CA5
# Inserting id: 935 lat: None lng: None
# Checking OKK
# Inserting id: 936 lat: 40.5290534 lng: -86.0579613827805
# Checking SGH
# Inserting id: 937 lat: 39.8402597 lng: -83.8411443391168
# Checking CSG
# Inserting id: 938 lat: 32.51660405 lng: -84.9420079018138
# Checking EAU
# Inserting id: 939 lat: 44.86902315 lng: -91.4855010804529
# Checking XNA
# Inserting id: 940 lat: 36.2797478 lng: -94.302561586289
# Checking KTW
# Inserting id: 941 lat: 50.47532995 lng: 19.0779294625102
# Checking AEP
# Inserting id: 942 lat: 16.52928375 lng: 80.7945682600193
# Checking ALC
# Inserting id: 943 lat: 38.2844177 lng: -0.56575284219804
# Checking EFL
# Inserting id: 944 lat: 38.12031905 lng: 20.5003002409682
# Checking PIC
# Inserting id: 945 lat: 31.3901626 lng: -100.4981504
# Checking SAW
# Inserting id: 946 lat: 40.89950505 lng: 29.3129653524179
# Checking UDJ
# Inserting id: 947 lat: 48.63564795 lng: 22.2608109329465
# Checking UKB
# Inserting id: 948 lat: 34.6341918 lng: 135.2290912
# Checking LRH
# Inserting id: 949 lat: 46.1769827 lng: -1.19146355185127
# Checking LRT
# Inserting id: 950 lat: 47.76118095 lng: -3.44310283803712
# Checking AHN
# Inserting id: 951 lat: 33.9487053 lng: -83.3297399781299
# Checking CAP
# Inserting id: 952 lat: -28.7889324 lng: 24.7713502
# Checking SVQ
# Inserting id: 953 lat: 37.41770835 lng: -5.89493134334505
# Checking XWM
# Inserting id: 954 lat: None lng: None
# Checking UTP
# Inserting id: 955 lat: 12.681415 lng: 101.001479719243
# Checking CVT
# Inserting id: 956 lat: 52.3699147 lng: -1.4812895374429
# Checking ALA
# Inserting id: 957 lat: 53.2716381 lng: 7.4587572
# Checking EIN
# Inserting id: 958 lat: 51.451235 lng: 5.37388083018868
# Checking FSC
# Inserting id: 959 lat: 41.50326675 lng: 9.09832663907909
# Checking RME
# Inserting id: 960 lat: 43.2322008 lng: -75.4143944486848
# Checking TUN
# Inserting id: 961 lat: 36.85184685 lng: 10.229475025552
# Checking HOW
# Inserting id: 962 lat: 45.0668053 lng: -88.4265808
# Checking CJS
# Inserting id: 963 lat: 31.63650975 lng: -106.42921686923
# Checking BOX
# Inserting id: 964 lat: 51.4108921 lng: -2.2200765
# Checking NUE
# Inserting id: 965 lat: 28.5693121 lng: 77.1234645
# Checking JRF
# Inserting id: 966 lat: 21.30839385 lng: -158.072522619383
# Checking FKS
# Inserting id: 967 lat: 37.2272 lng: 140.4306
# Checking IZO
# Inserting id: 968 lat: 35.41314345 lng: 132.887817882428
# Checking KLU
# Inserting id: 969 lat: 46.64348 lng: 14.3286479327237
# Checking NOC
# Inserting id: 970 lat: 53.91159225 lng: -8.81313884580053
# Checking JMK
# Inserting id: 971 lat: 37.43495305 lng: 25.347144567377
# Checking BVY
# Inserting id: 972 lat: 42.58617415 lng: -70.9170584615987
# Checking EWB
# Inserting id: 973 lat: 41.6774475 lng: -70.9600420219756
# Checking ZXU
# Inserting id: 974 lat: None lng: None
# Checking MRC
# Inserting id: 975 lat: 35.5548206 lng: -87.1800643125152
# Checking BFL
# Inserting id: 976 lat: 35.4372678 lng: -119.059223660743
# Checking RKV
# Inserting id: 977 lat: 64.129393 lng: -21.9409444551476
# Checking ADK
# Inserting id: 978 lat: 6.1723857 lng: 1.2531584
# Checking SHE
# Inserting id: 979 lat: 22.3161394 lng: 113.93644473373
# Checking BRE
# Inserting id: 980 lat: 53.04534175 lng: 8.78964164518344
# Checking BTS
# Inserting id: 981 lat: 48.17232305 lng: 17.2134665861767
# Checking BOB
# Inserting id: 982 lat: -16.4445566 lng: -151.7524271
# Checking MVY
# Inserting id: 983 lat: 41.3924156 lng: -70.6145722277191
# Checking QSR
# Inserting id: 984 lat: 40.61887125 lng: 14.9111031454236
# Checking KUV
# Inserting id: 985 lat: 35.90720495 lng: 126.622068607145
# Checking HIF
# Inserting id: 986 lat: 33.8677763 lng: 35.5531038
# Checking LLA
# Inserting id: 987 lat: 65.5483042 lng: 22.1214883
# Checking NZY
# Inserting id: 988 lat: -17.5567557 lng: -149.6114116
# Checking BZZ
# Inserting id: 989 lat: 51.7511241 lng: -1.57939330096555
# Checking BLQ
# Inserting id: 990 lat: 44.5344604 lng: 11.2884958500512
# Checking AVP
# Inserting id: 991 lat: 41.33713525 lng: -75.7225490617848
# Checking YGK
# Inserting id: 992 lat: 4.94213885 lng: 114.929573040735
# Checking SLK
# Inserting id: 993 lat: 44.38940195 lng: -74.204655569888
# Checking CEF
# Inserting id: 994 lat: 55.8719444 lng: -4.4330556
# Checking YCM
# Inserting id: 995 lat: 43.1929769 lng: -79.171941751618
# Checking YZV
# Inserting id: 996 lat: 50.2233009 lng: -66.2656021
# Checking C01
# Inserting id: 997 lat: 34.2069018 lng: -119.0763189
# Checking NKC
# Inserting id: 998 lat: 18.09598525 lng: -15.9477583294428
# Checking MSJ
# Inserting id: 999 lat: 40.70130095 lng: 141.37178603846
# Checking UAB
# Inserting id: 1000 lat: 41.5218892 lng: 2.10384403839652
# Checking YEV
# Inserting id: 1001 lat: 68.3056164 lng: -133.4900365
# Checking YZF
# Inserting id: 1002 lat: 62.4709394 lng: -114.4384901
# Checking OTP
# Inserting id: 1003 lat: 44.56802255 lng: 26.0987520154544
# Checking BLL
# Inserting id: 1004 lat: 55.7411782 lng: 9.16074608624515
# Checking MED
# Inserting id: 1005 lat: 32.73336075 lng: -117.192246412776
# Checking ALG
# Inserting id: 1006 lat: 36.701292 lng: 3.21105215946994
# Checking HUF
# Inserting id: 1007 lat: 39.44968565 lng: -87.3034872975212
# Checking FNA
# Inserting id: 1008 lat: 8.61700785 lng: -13.1985594161178
# Checking DEC
# Inserting id: 1009 lat: 39.83314345 lng: -88.8652047216778
# Checking TBS
# Inserting id: 1010 lat: 41.6696684 lng: 44.9550650273924
# Checking TIV
# Inserting id: 1011 lat: 42.4035781 lng: 18.7250147433629
# Checking KLX
# Inserting id: 1012 lat: 37.0676599 lng: 22.025615
# Checking RIL
# Inserting id: 1013 lat: 39.5253565 lng: -107.725348136985
# Checking SPU
# Inserting id: 1014 lat: 43.5397753 lng: 16.3002241638655
# Checking TFN
# Inserting id: 1015 lat: 28.48275745 lng: -16.3412247450223
# Checking KOS
# Inserting id: 1016 lat: 50.3146532 lng: 66.951956
# Checking BTR
# Inserting id: 1017 lat: 30.5319743 lng: -91.1503775351041
# Checking CME
# Inserting id: 1018 lat: 18.6519282 lng: -91.8012708310294
# Checking ABI
# Inserting id: 1019 lat: 32.40774375 lng: -99.6793703396851
# Checking VSA
# Inserting id: 1020 lat: 17.9959326 lng: -92.8192292
# Checking CLL
# Inserting id: 1021 lat: 43.62805705 lng: -79.3979911558998
# Checking SJT
# Inserting id: 1022 lat: 31.35468635 lng: -100.498624549389
# Checking SBN
# Inserting id: 1023 lat: 41.7100063 lng: -86.3186693482443
# Checking LAR
# Inserting id: 1024 lat: 41.3134545 lng: -105.672865393546
# Checking FWA
# Inserting id: 1025 lat: 40.9798288 lng: -85.1879046010707
# Checking ACT
# Inserting id: 1026 lat: 31.6133017 lng: -97.2263861620854
# Checking YAP
# Inserting id: 1027 lat: 9.4996597 lng: 138.0832159
# Checking AXM
# Inserting id: 1028 lat: 4.45028775 lng: -75.766546674964
# Checking DCF
# Inserting id: 1029 lat: 15.3377572 lng: -61.3928993
# Checking VLN
# Inserting id: 1030 lat: 10.1501416 lng: -67.928814
# Checking CCC
# Inserting id: 1031 lat: 39.7343661 lng: -94.1927957
# Checking MZO
# Inserting id: 1032 lat: 20.2876589 lng: -77.092605184411
# Checking LPB
# Inserting id: 1033 lat: -16.51231085 lng: -68.1902731555442

# %%
geocoder.osm("Brooksville, FL airport")

# %% [markdown]
# Checking JZQ
# Inserting id: 432 lat: None lng: None

# %%
airports[413].id
# Out:
# 414

# %%
there are duplicates which I need to remove.
